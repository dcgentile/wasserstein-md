# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import ot
from tqdm import tqdm

# %%
data_folder= os.path.join('..', 'data')
raw_angles = os.path.join(data_folder, 'A_2D_1ps.dat')
shifted_angles = os.path.join(data_folder, 'ADP_2D.txt')
shifted_df = pd.read_csv(shifted_angles, sep=' ', names=['phi', 'psi'])
df = pd.read_csv(raw_angles, sep=' ', names=['phi', 'psi'])
df['rescaled_phi'] = (180 + df['phi']) / 360
df['rescaled_psi'] = (180 + df['psi']) / 360

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(16, 8)
sns.lineplot(shifted_df['phi'], ax=ax1)
sns.lineplot(shifted_df['psi'], ax=ax2)
ax1.set_title(r"$\varphi$")
ax2.set_title(r"$\psi$")
ax1.set_ylabel("Angle (Shifted)")
ax2.set_ylabel("Angle (Shifted)")
ax1.set_xlabel("Time")
ax2.set_xlabel("Time")
plt.savefig("nonperiodic-angle-series.pdf", bbox_inches="tight")

# %%
def changes(data, windowsize):
    sample_count = data.shape[0]
    arr = data.to_numpy()
    differences = np.zeros(sample_count)
    for t in range(windowsize, sample_count - windowsize):
        sample_a = arr[t - windowsize:t]
        sample_b = arr[t: t + windowsize]
        differences[t] = ot.wasserstein_circle(sample_a, sample_b, p=2)
    result = pd.Series(differences)
    return differences

# %%
for w in tqdm(range(100, 1100, 100)):
    df[f'dw_phi_{w}'] = changes(df['rescaled_phi'], w)
    df[f'dw_psi_{w}'] = changes(df['rescaled_psi'], w)
# Out:
#   0% 0/10 [00:45<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 for w in tqdm(range(100, 1100, 100)):
# ----> 2     df[f'dw_phi_{w}'] = changes(df['rescaled_phi'], w)
#       3     df[f'dw_psi_{w}'] = changes(df['rescaled_psi'], w)
#
# Cell In[5], line 8, in changes(data, windowsize)
#       6     sample_a = arr[t - windowsize:t]
#       7     sample_b = arr[t: t + windowsize]
# ----> 8     differences[t] = ot.wasserstein_circle(sample_a, sample_b, p=2)
#       9 result = pd.Series(differences)
#      10 return differences
#
# File /usr/local/lib/python3.11/site-packages/ot/lp/solver_1d.py:923, in wasserstein_circle(u_values, v_values, u_weights, v_weights, p, Lm, Lp, tm, tp, eps, require_sort)
#     920 if p == 1:
#     921     return wasserstein1_circle(u_values, v_values, u_weights, v_weights, require_sort)
# --> 923 return binary_search_circle(u_values, v_values, u_weights, v_weights,
#     924                             p=p, Lm=Lm, Lp=Lp, tm=tm, tp=tp, eps=eps,
#     925                             require_sort=require_sort)
#
# File /usr/local/lib/python3.11/site-packages/ot/lp/solver_1d.py:720, in binary_search_circle(u_values, v_values, u_weights, v_weights, p, Lm, Lp, tm, tp, eps, require_sort, log)
#     717 while nx.any(1 - done):
#     718     cpt += 1
# --> 720     dCp, dCm = derivative_cost_on_circle(tc, u_values, v_values, u_cdf, v_cdf, p)
#     721     done = ((dCp * dCm) <= 0) * 1
#     723     mask = ((tp - tm) < eps / L) * (1 - done)
#
# File /usr/local/lib/python3.11/site-packages/ot/lp/solver_1d.py:469, in derivative_cost_on_circle(theta, u_values, v_values, u_cdf, v_cdf, p)
#     466 shift = (-nx.argmin(v_cdf_theta2, axis=-1))
#     468 v_cdf_theta = roll_cols(v_cdf_theta, nx.reshape(shift, (-1, 1)))
# --> 469 v_values = roll_cols(v_values, nx.reshape(shift, (-1, 1)))
#     470 v_values = nx.concatenate([v_values, nx.reshape(v_values[:, 0], (-1, 1)) + 1], axis=1)
#     472 if nx.__name__ == 'torch':
#     473     # this is to ensure the best performance for torch searchsorted
#     474     # and avoid a warning related to non-contiguous arrays
#
# File /usr/local/lib/python3.11/site-packages/ot/lp/solver_1d.py:414, in roll_cols(M, shifts)
#     411 arange1 = nx.tile(nx.reshape(nx.arange(n_cols, type_as=shifts), (1, n_cols)), (n_rows, 1))
#     412 arange2 = (arange1 - shifts) % n_cols
# --> 414 return nx.take_along_axis(M, arange2, 1)
#
# File /usr/local/lib/python3.11/site-packages/ot/backend.py:1135, in NumpyBackend.take_along_axis(self, arr, indices, axis)
#    1134 def take_along_axis(self, arr, indices, axis):
# -> 1135     return np.take_along_axis(arr, indices, axis)
#
# File <__array_function__ internals>:200, in take_along_axis(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/numpy/lib/shape_base.py:170, in take_along_axis(arr, indices, axis)
#     167     arr_shape = arr.shape
#     169 # use the fancy index
# --> 170 return arr[_make_along_axis_idx(arr_shape, indices, axis)]
#
# File /usr/local/lib/python3.11/site-packages/numpy/lib/shape_base.py:47, in _make_along_axis_idx(arr_shape, indices, axis)
#      45     else:
#      46         ind_shape = shape_ones[:dim] + (-1,) + shape_ones[dim+1:]
# ---> 47         fancy_index.append(_nx.arange(n).reshape(ind_shape))
#      49 return tuple(fancy_index)
#
# KeyboardInterrupt:
#  25% 2/8 [03:02<09:09, 91.61s/it]
#  38% 3/8 [04:49<08:12, 98.40s/it]
#  50% 4/8 [07:00<07:26, 111.59s/it]
#  62% 5/8 [24:28<22:27, 449.25s/it]
#  75% 6/8 [27:12<11:44, 352.19s/it]
#  88% 7/8 [30:20<04:58, 298.46s/it]
# 100% 8/8 [33:28<00:00, 263.36s/it]
# 100% 8/8 [33:28<00:00, 251.08s/it]

# %%
df.describe()

# %%
phi_frame = df[['dw_phi_100', 'dw_phi_300', 'dw_phi_500', 'dw_phi_700',]]
psi_frame = df[['dw_psi_100', 'dw_psi_300', 'dw_psi_500', 'dw_psi_700',]]

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
fig.set_size_inches(16,8)
sns.lineplot(psi_frame, ax=ax1)
sns.lineplot(phi_frame, ax=ax2)
ax1.set_title(r'$\varphi$')
ax2.set_title(r'$\psi$')
plt.show()
